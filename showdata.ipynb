# %%
import pandas as pd
from matplotlib import pyplot as plt
import json 

global df 
df = pd.DataFrame(columns= ["Name", "Age", "Gender", "Race", "Education", "Employment_Status", "Veteran_Status"])
with open('/workspaces/refactored-pancake/data.json') as f:
    data = json.load(f)

# %%
from request import participant_arr

# %%
for x in participant_arr:
    df.loc[participant_arr.index(x)] = [x.name, x.age, x.gender, x.race, x.education, x.employment_status, x.served]

# %%
df
# Out:
#                     Name Age  Gender                               Race  \
# 0        Nina Blackshear  63  Female          Black or African American
# 1          jordan miller  26    Male  Native American or Alaskan Native
# 2          Nate Johnston  29    Male                 White or Caucasian
# 3   Marlene Sullenberger  55  Female                 White or Caucasian
# 4          Charmaine Ray  67  Female          Black or African American
# ..                   ...  ..     ...                                ...
# 78          Taylor Riggs  33    Male                 White or Caucasian
# 79         Mark Anderson  42    Male                 White or Caucasian
# 80         Cedric Graves  44    Male          Black or African American
# 81        conrad strader  18    Male          Black or African American
# 82  Charles L. Yancey II  41    Male          Black or African American
#
#                   Education Employment_Status Veteran_Status
# ...
